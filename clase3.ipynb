# %% [markdown]
# <a href="https://colab.research.google.com/github/mariasophiava/dataset-/blob/main/clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Clase 3

# %%
path= 'https://raw.githubusercontent.com/mariasophiava/dataset-/main/Cartwheeldata.csv'

# %%
import pandas as pd

# %%
df=pd.read_csv(path)
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      0
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
nCls = df.columns.sort_values()
nCls
# Out:
# Index(['Age', 'CWDistance', 'Complete', 'CompleteGroup', 'Gender',
#        'GenderGroup', 'Glasses', 'GlassesGroup', 'Height', 'ID', 'Score',
#        'Wingspan'],
#       dtype='object')

# %%
type(nCls)
# Out:
# pandas.core.indexes.base.Index

# %%
df.shape
# Out:
# (25, 12)

# %%
df.Age
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
ageData=df.Age
ageData
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
type(ageData)
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
ageData2=df['Age']
ageData2
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
ageData3=df[['Age']]
ageData3
# Out:
#     Age
# 0    56
# 1    26
# 2    33
# 3    39
# 4    27
# 5    24
# 6    28
# 7    22
# 8    29
# 9    33
# 10   30
# 11   28
# 12   25
# 13   23
# 14   31
# 15   26
# 16   26
# 17   27
# 18   23
# 19   24
# 20   23
# 21   29
# 22   25
# 23   26
# 24   23

# %%
favs= ['Age','Gender']
df[favs]
# Out:
#     Age Gender
# 0    56      F
# 1    26      F
# 2    33      F
# 3    39      F
# 4    27      M
# 5    24      M
# 6    28      M
# 7    22      F
# 8    29      M
# 9    33      F
# 10   30      M
# 11   28      F
# 12   25      F
# 13   23      F
# 14   31      M
# 15   26      M
# 16   26      F
# 17   27      M
# 18   23      M
# 19   24      F
# 20   23      M
# 21   29      M
# 22   25      M
# 23   26      M
# 24   23      F

# %%
favs=df[['Age','Gender']]
favs
# Out:
#     Age Gender
# 0    56      F
# 1    26      F
# 2    33      F
# 3    39      F
# 4    27      M
# 5    24      M
# 6    28      M
# 7    22      F
# 8    29      M
# 9    33      F
# 10   30      M
# 11   28      F
# 12   25      F
# 13   23      F
# 14   31      M
# 15   26      M
# 16   26      F
# 17   27      M
# 18   23      M
# 19   24      F
# 20   23      M
# 21   29      M
# 22   25      M
# 23   26      M
# 24   23      F

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %% [markdown]
# *   primera 4 columns
# *   ultima 4 columns
# *   solo columns gender, gendergroup, glasses,height,complete

# %%
prim=df[['ID', 'Age', 'Gender', 'GenderGroup']]
prim
# Out:
#     ID  Age Gender  GenderGroup
# 0    1   56      F            1
# 1    2   26      F            1
# 2    3   33      F            1
# 3    4   39      F            1
# 4    5   27      M            2
# 5    6   24      M            2
# 6    7   28      M            2
# 7    8   22      F            1
# 8    9   29      M            2
# 9   10   33      F            1
# 10  11   30      M            2
# 11  12   28      F            1
# 12  13   25      F            1
# 13  14   23      F            1
# 14  15   31      M            2
# 15  16   26      M            2
# 16  17   26      F            1
# 17  18   27      M            2
# 18  19   23      M            2
# 19  20   24      F            1
# 20  21   23      M            2
# 21  22   29      M            2
# 22  23   25      M            2
# 23  24   26      M            2
# 24  25   23      F            1

# %%
favs=df.iloc[0:,:4]
favs
# Out:
#     ID  Age Gender  GenderGroup
# 0    1   56      F            1
# 1    2   26      F            1
# 2    3   33      F            1
# 3    4   39      F            1
# 4    5   27      M            2
# 5    6   24      M            2
# 6    7   28      M            2
# 7    8   22      F            1
# 8    9   29      M            2
# 9   10   33      F            1
# 10  11   30      M            2
# 11  12   28      F            1
# 12  13   25      F            1
# 13  14   23      F            1
# 14  15   31      M            2
# 15  16   26      M            2
# 16  17   26      F            1
# 17  18   27      M            2
# 18  19   23      M            2
# 19  20   24      F            1
# 20  21   23      M            2
# 21  22   29      M            2
# 22  23   25      M            2
# 23  24   26      M            2
# 24  25   23      F            1

# %% [markdown]
# *  loc(string) y iloc(numeros)
#
#
#
# 1.   df.loc[fila del inicio: fila del final,columna nombre inicio:columna nombre final]
# 2.   df.iloc[fila numero inicio:fila numero final,columna numero inicio:columna numero final]

# %% [markdown]
# *df.loc[row_name_start:row_name_end, column_name_start:column_name_end]*
#
# *df.iloc[row_index_start:row_index_end, column_index_start:column_index_end]*

# %%
df.loc[:,:'GenderGroup']
# Out:
#     ID  Age Gender  GenderGroup
# 0    1   56      F            1
# 1    2   26      F            1
# 2    3   33      F            1
# 3    4   39      F            1
# 4    5   27      M            2
# 5    6   24      M            2
# 6    7   28      M            2
# 7    8   22      F            1
# 8    9   29      M            2
# 9   10   33      F            1
# 10  11   30      M            2
# 11  12   28      F            1
# 12  13   25      F            1
# 13  14   23      F            1
# 14  15   31      M            2
# 15  16   26      M            2
# 16  17   26      F            1
# 17  18   27      M            2
# 18  19   23      M            2
# 19  20   24      F            1
# 20  21   23      M            2
# 21  22   29      M            2
# 22  23   25      M            2
# 23  24   26      M            2
# 24  25   23      F            1

# %%
df.loc[:,'CWDistance':]
# Out:
#     CWDistance Complete  CompleteGroup  Score
# 0           79        Y              1      7
# 1           70        Y              1      8
# 2           85        Y              1      0
# 3           87        Y              1     10
# 4           72        N              0      4
# 5           81        N              0      3
# 6          107        Y              1     10
# 7           98        Y              1      9
# 8          106        N              0      5
# 9           65        Y              1      8
# 10          96        Y              1      6
# 11          79        Y              1     10
# 12          92        Y              1      6
# 13          66        Y              1      4
# 14          72        Y              1      9
# 15         115        Y              1      6
# 16          90        N              0     10
# 17          74        Y              1      5
# 18          64        Y              1      3
# ...

# %%
df.iloc[:,8:]
# Out:
#     CWDistance Complete  CompleteGroup  Score
# 0           79        Y              1      7
# 1           70        Y              1      8
# 2           85        Y              1      0
# 3           87        Y              1     10
# 4           72        N              0      4
# 5           81        N              0      3
# 6          107        Y              1     10
# 7           98        Y              1      9
# 8          106        N              0      5
# 9           65        Y              1      8
# 10          96        Y              1      6
# 11          79        Y              1     10
# 12          92        Y              1      6
# 13          66        Y              1      4
# 14          72        Y              1      9
# 15         115        Y              1      6
# 16          90        N              0     10
# 17          74        Y              1      5
# 18          64        Y              1      3
# ...

# %%
df.iloc[:,-4:]
# Out:
#     CWDistance Complete  CompleteGroup  Score
# 0           79        Y              1      7
# 1           70        Y              1      8
# 2           85        Y              1      0
# 3           87        Y              1     10
# 4           72        N              0      4
# 5           81        N              0      3
# 6          107        Y              1     10
# 7           98        Y              1      9
# 8          106        N              0      5
# 9           65        Y              1      8
# 10          96        Y              1      6
# 11          79        Y              1     10
# 12          92        Y              1      6
# 13          66        Y              1      4
# 14          72        Y              1      9
# 15         115        Y              1      6
# 16          90        N              0     10
# 17          74        Y              1      5
# 18          64        Y              1      3
# ...

# %%
df.loc[5:10,['Age','Complete']]
# Out:
#     Age Complete
# 5    24        N
# 6    28        Y
# 7    22        Y
# 8    29        N
# 9    33        Y
# 10   30        Y

# %%
FAV=df.iloc[5:11,[1,9]]
FAV
# Out:
#     Age Complete
# 5    24        N
# 6    28        Y
# 7    22        Y
# 8    29        N
# 9    33        Y
# 10   30        Y

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.Glasses.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
favs=['Gender','Glasses']
df.groupby(favs).size()
# Out:
# Gender  Glasses
# F       N          4
#         Y          8
# M       N          7
#         Y          6
# dtype: int64

# %%
type(df[favs])
# Out:
# pandas.core.frame.DataFrame

# %%
df[favs].value_counts()
# Out:
# Gender  Glasses
# F       Y          8
# M       N          7
#         Y          6
# F       N          4
# dtype: int64
